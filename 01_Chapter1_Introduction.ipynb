# %% [markdown]
# # Chapter 1 - Introduction
#
# ## Summary
# Chapter ini membahas dasar linear algebra dalam data science.
#
# ## Konsep Utama
# - Vektor
# - Matriks
# - Representasi data
#
# ## Penjelasan
# Linear algebra digunakan dalam machine learning untuk merepresentasikan dan memproses data.

# %%
import numpy as np

v = np.array([1,2,3])
print(v)
# Out:
# [1 2 3]
